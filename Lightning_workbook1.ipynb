# %% [markdown]
# <a href="https://colab.research.google.com/github/dougc333/meetup_colab/blob/main/Lightning_workbook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lightning Workbook

# %%
import torch
torch.__version__
# Out:
# '2.6.0+cu124'

# %%
#copied from pytorch lightning, no nemo install.
#25m to install and it is missing nemo install
# torch
# !pip install "torch==2.2.1" --index-url https://download.pytorch.org/whl/cu121
# nvidia apex
# !pip install -v --disable-pip-version-check --no-cache-dir --no-build-isolation --config-settings --build-option=--cpp_ext --config-settings --build-option=--cuda_ext git+https://github.com/NVIDIA/apex.git@24.04.01
# megatron-core
# !pip install "megatron-core==0.9.0"
# nemo-run
# !pip install git+https://github.com/NVIDIA/NeMo-Run.git@6b00501e68d56070bb4fb9808ab11bb8d0f03b51
# flash-attn
# see https://github.com/NVIDIA/TransformerEngine/issues/1236
# !pip install "flash-attn<2.5.7"
# nvidia transformer-engine
# !pip install "transformer-engine[pytorch]==1.11.0"
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# ERROR: Invalid requirement: '!git+https://github.com/NVIDIA/apex.git@24.04.01': Expected package name at the start of dependency specifier
#     !git+https://github.com/NVIDIA/apex.git@24.04.01
#     ^
# Hint: It looks like a path. File '!git+https://github.com/NVIDIA/apex.git@24.04.01' does not exist.
# ...
#   Cloning https://github.com/NVIDIA/NeMo-Run.git (to revision 6b00501e68d56070bb4fb9808ab11bb8d0f03b51) to /tmp/pip-req-build-y5f6254l
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo-Run.git /tmp/pip-req-build-y5f6254l
#   Running command git rev-parse -q --verify 'sha^6b00501e68d56070bb4fb9808ab11bb8d0f03b51'
#   Running command git fetch -q https://github.com/NVIDIA/NeMo-Run.git 6b00501e68d56070bb4fb9808ab11bb8d0f03b51
#   Running command git checkout -q 6b00501e68d56070bb4fb9808ab11bb8d0f03b51
# ...

# %%
# these 2 didnt install bc no pip install
#apex doesnt install need to install in terminal
#!pip install git+https://github.com/NVIDIA/apex.git@24.04.01
# !pip install git+https://github.com/NVIDIA/NeMo-Run.git@6b00501e68d56070bb4fb9808ab11bb8d0f03b51
# Out:
# ...
#   Cloning https://github.com/NVIDIA/apex.git (to revision 24.04.01) to /tmp/pip-req-build-p8hn0o2z
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/apex.git /tmp/pip-req-build-p8hn0o2z
#   Running command git checkout -q 4138d31ff0acf4071d1dc001ccb7cd6e00800324
#   Resolved https://github.com/NVIDIA/apex.git to commit 4138d31ff0acf4071d1dc001ccb7cd6e00800324
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# !pip install meetup-colab

# %%
from meetup_colab import nvidia
nvidia.update_12_4()
#nvidia.install_nemo()
# Out:
# colab_dc333.update_12_4 downgrades colab from cuda12.5 to cuda12.4 to make nvcc and nvidia-smi match
# this takes 5minutes, please wait ...

# %%
#verify nvcc is 12.4
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Mar_28_02:18:24_PDT_2024
# Cuda compilation tools, release 12.4, V12.4.131
# Build cuda_12.4.r12.4/compiler.34097967_0

# %%
# !pip install git+https://github.com/NVIDIA/NeMo-Run.git
# Out:
# ...
#   Cloning https://github.com/NVIDIA/NeMo-Run.git to /tmp/pip-req-build-j9xcn9rl
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo-Run.git /tmp/pip-req-build-j9xcn9rl
#   Resolved https://github.com/NVIDIA/NeMo-Run.git to commit f3c3ac22fe169acf93aa7647ab9785290537d4a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 105.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 27.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 15.8 MB/s eta 0:00:00
# ...

# %%
import nemo_run as run

# %%
# !pip install megatron-core

# %%
#!pip install nemo_toolkit[all]
# !pip install -v --disable-pip-version-check nemo_toolkit[all]
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# ...
#   Obtaining dependency information for urllib3!=2.2.0,<3,>=1.25.4 from https://files.pythonhosted.org/packages/6b/11/cc635220681e93a0183390e26485430ca2c7b5f9d33b15c74c2861cb8091/urllib3-2.4.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.20
#     Uninstalling urllib3-1.26.20:
#       Removing file or directory /usr/local/lib/python3.11/dist-packages/urllib3-1.26.20.dist-info/
#       Removing file or directory /usr/local/lib/python3.11/dist-packages/urllib3/
#       Successfully uninstalled urllib3-1.26.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install transformer-engine[pytorch]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.8/218.8 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.1/432.1 kB 37.5 MB/s eta 0:00:00
# ...
#   Created wheel for transformer_engine_torch: filename=transformer_engine_torch-2.2.0-cp311-cp311-linux_x86_64.whl size=36568835 sha256=ce7c018f6a5e3f607f484e3f0148e6ee52d1dffbb7c168f87e326765b8b1f919
#   Stored in directory: /root/.cache/pip/wheels/93/34/40/585f3bcff9705a4e3975a470e92c7f27df9145e8b16aeed8a1
# Successfully built transformer_engine_torch
# ...

# %%
import transformer_engine
print(transformer_engine.__version__)
print(dir(transformer_engine))  # should include 'pytorch'
# Out:
# 2.2.0
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'common', 'metadata', 'pytorch', 'transformer_engine']

# %%
#takes 17m! Do not install unless needed
# !pip install --disable-pip-version-check --no-build-isolation git+https://github.com/state-spaces/mamba.git
# Out:
# ...
#   Cloning https://github.com/state-spaces/mamba.git to /tmp/pip-req-build-3ww37its
#   Running command git clone --filter=blob:none --quiet https://github.com/state-spaces/mamba.git /tmp/pip-req-build-3ww37its
#   Resolved https://github.com/state-spaces/mamba.git to commit 4a8a2a2ac9a1ed4aee2edb9207f41421ca11c5a4
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# install nvidia apex. have to git clone and run SPECIAL pip install command
# do not install unless need to convert .nemo files!
#pip install -v --disable-pip-version-check --no-build-isolation --no-cache-dir ./
# !pip install -v --disable-pip-version-check --no-build-isolation --no-cache-dir  git+https://github.com/NVIDIA/apex.git
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# ...
#   Cloning https://github.com/NVIDIA/apex.git to /tmp/pip-req-build-lc2f4qk6
#   Running command git version
#   git version 2.34.1
#   Running command git clone --filter=blob:none https://github.com/NVIDIA/apex.git /tmp/pip-req-build-lc2f4qk6
#   Cloning into '/tmp/pip-req-build-lc2f4qk6'...
#   Running command git rev-parse HEAD
#   cb65b8ed2be7105b80898d04c4d63bb0c57f69af
#   Resolved https://github.com/NVIDIA/apex.git to commit cb65b8ed2be7105b80898d04c4d63bb0c57f69af
#   Running command git submodule update --init --recursive -q
#   Running command git rev-parse HEAD
#   cb65b8ed2be7105b80898d04c4d63bb0c57f69af
#   Running command Preparing metadata (pyproject.toml)
#
#
#   torch.__version__  = 2.6.0+cu124
#
#
#   running dist_info
#   creating /tmp/pip-modern-metadata-1r8k5wyo/apex.egg-info
#   writing /tmp/pip-modern-metadata-1r8k5wyo/apex.egg-info/PKG-INFO
# ...

# %%
from nemo.collections import llm
# Out:
# [NeMo W 2025-05-09 21:09:10 nemo_logging:405] The package `megatron.core` was not imported in this environment which is needed for SSMs.
# [NeMo W 2025-05-09 21:09:10 nemo_logging:405] Failed to import nemo.collections.llm.[api,recipes]: mamba-ssm is required by the Mamba model but cannot be imported
# [NeMo W 2025-05-09 21:09:10 nemo_logging:405] The deploy module could not be imported: mamba-ssm is required by the Mamba model but cannot be imported
# [NeMo W 2025-05-09 21:09:10 nemo_logging:405] The evaluate module could not be imported: mamba-ssm is required by the Mamba model but cannot be imported

# %%
#copy to /content/drive/MyDrive/nemotron_pretraining.py

# %%
# code adapted from NeMo 2.0 documentation
# see https://docs.nvidia.com/nemo-framework/user-guide/latest/nemo-2.0/quickstart.html

import nemo_run as run

from nemo.collections import llm
from nemo.collections.llm import Nemotron3Config4B
#dir(Nemotron3Config4B)
def configure_recipe(
    nodes: int = 1,
    gpus_per_node: int = 1,
    max_steps: int = 100,
    val_check_interval: int = 10,
):
    recipe = llm.nemotron3_4b.pretrain_recipe(
        dir="./checkpoints/nemotron",  # Path to store checkpoints
        name="nemotron_pretraining",
        tensor_parallelism=1,
        num_nodes=nodes,
        num_gpus_per_node=gpus_per_node,
        max_steps=max_steps,  # Setting a small value for the quickstart
    )
    # see https://pytorch-lightning.readthedocs.io/en/2.4.0/pytorch/common/trainer.html#
    recipe.trainer.val_check_interval = val_check_interval
    # recipe.trainer.strategy = "auto"  # try to override megatron strategy
    recipe.model.config.num_layers = 8
    return recipe


def local_executor_torchrun(nodes: int = 1, devices: int = 1) -> run.LocalExecutor:
    # Env vars for jobs are configured here
    env_vars = {
        "TORCH_NCCL_AVOID_RECORD_STREAMS": "1",
        "NCCL_NVLS_ENABLE": "0",
        "NVTE_DP_AMAX_REDUCE_INTERVAL": "0",
        "NVTE_ASYNC_AMAX_REDUCTION": "1",
        "NVTE_FUSED_ATTN": "0",
        "CUDA_VISIBLE_DEVICES": "0",
    }

    executor = run.LocalExecutor(
        ntasks_per_node=devices,
        env_vars=env_vars,
        launcher="torchrun",
    )

    return executor


def run_pretraining():
    recipe = configure_recipe()
    executor = local_executor_torchrun(
        nodes=recipe.trainer.num_nodes,
        devices=recipe.trainer.devices,
    )

    run.run(recipe, executor=executor)


# This condition is necessary for the script to be compatible with Python's multiprocessing module.
if __name__ == "__main__":
    run_pretraining()
